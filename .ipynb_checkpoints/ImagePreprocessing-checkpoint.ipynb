# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import time

# %%
vid_name = "02-10"
rank = 10
video = cv2.VideoCapture(vid_name + ".MOV")
_, frame = video.read()

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
resize_crop = cv2.resize(gray, (90, 160))
plt.imshow(resize_crop, cmap="gray")

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
resize_crop = resize_crop.flatten()
scaled = scaler.fit_transform(resize_crop.reshape(-1, 1))
scaled = np.append(np.array([rank]), scaled).reshape(1, -1)
global df
df = pd.DataFrame(scaled)
df
# Out:
#    0         1         2         3         4         5         6      \
# 0   10.0  0.380952  0.365079  0.349206  0.365079  0.376984  0.384921
#
#       7         8         9      ...     14391     14392     14393     14394  \
# 0  0.369048  0.376984  0.384921  ...  0.115079  0.111111  0.027778  0.039683
#
#       14395     14396     14397     14398     14399     14400
# 0  0.059524  0.115079  0.309524  0.337302  0.206349  0.277778
#
# [1 rows x 14401 columns]

# %%
def get_frame(sec):
    video.set(cv2.CAP_PROP_POS_MSEC, sec*1000)
    success, image = video.read()
    return success, image

# %%
def get_data(sec):
    global df
    start = time.time()
    success, image  = get_frame(sec)
    if not success:
        return
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(gray, (90, 160))
    scaled = scaler.fit_transform(resized).flatten()
    scaled = np.append(np.array([rank]), scaled).flatten()
    df = df.append(pd.Series(scaled), ignore_index=True)

# %%
start = time.time()
for i in range(1, 600, 10):
    elapsed = time.time() - start
    done = i/600
    estimate = int(elapsed/done - elapsed)
    print(f"Currently at {i//60} minutes and {i%60} seconds -- Estimated {estimate}s left          ", end="\r")
    
    get_data(i)

print(f"\nTook {elapsed} seconds to run")
df
# Out:
# Currently at 9 minutes and 51 seconds -- Estimated 0s left
# Took 16.285792350769043 seconds to run
#     0         1         2         3         4         5         6      \
# 0    10.0  0.380952  0.365079  0.349206  0.365079  0.376984  0.384921
# 1    10.0  0.401015  0.435644  0.338645  0.333333  0.324000  0.344130
# 2    10.0  0.435897  0.402062  0.322314  0.354582  0.337349  0.358566
# 3    10.0  0.410811  0.475410  0.334677  0.322449  0.318725  0.286290
# 4    10.0  0.420213  0.391534  0.351020  0.355102  0.340081  0.357430
# ..    ...       ...       ...       ...       ...       ...       ...
# 56   10.0  0.451429  0.455556  0.346939  0.323770  0.342742  0.315789
# 57   10.0  0.472826  0.442708  0.341463  0.327801  0.334694  0.368421
# 58   10.0  0.488372  0.491620  0.338710  0.315574  0.329317  0.357430
# 59   10.0  0.415789  0.394089  0.317073  0.313008  0.340081  0.345528
# 60   10.0  0.434555  0.425743  0.342857  0.334694  0.345382  0.318725
#
#        7         8         9      ...     14391     14392     14393     14394  \
# 0   0.369048  0.376984  0.384921  ...  0.115079  0.111111  0.027778  0.039683
# 1   0.315789  0.351240  0.314286  ...  0.151515  0.093567  0.045198  0.064516
# 2   0.361111  0.329268  0.315789  ...  0.198830  0.088235  0.005952  0.010753
# 3   0.317073  0.325203  0.303279  ...  0.186335  0.062893  0.000000  0.056497
# 4   0.338710  0.319672  0.309917  ...  0.220339  0.064000  0.055556  0.054645
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 56  0.318367  0.325203  0.327935  ...  0.176871  0.100719  0.043210  0.038251
# 57  0.341463  0.320988  0.340164  ...  0.155172  0.090361  0.036364  0.016484
# 58  0.330612  0.349794  0.334694  ...  0.119048  0.094937  0.049080  0.027624
# 59  0.336032  0.333333  0.337349  ...  0.128834  0.141104  0.018868  0.032967
# 60  0.370518  0.336032  0.318548  ...  0.128655  0.119760  0.075000  0.016667
#
#        14395     14396     14397     14398     14399     14400
# 0   0.059524  0.115079  0.309524  0.337302  0.206349  0.277778
# 1   0.005814  0.159794  0.355556  0.431034  0.346369  0.390110
# 2   0.028902  0.206349  0.494253  0.426966  0.400000  0.441860
# 3   0.012422  0.167568  0.458824  0.395210  0.349112  0.416185
# 4   0.050562  0.145833  0.366279  0.374269  0.314607  0.361111
# ..       ...       ...       ...       ...       ...       ...
# 56  0.040936  0.161458  0.360000  0.349727  0.294444  0.373563
# 57  0.016949  0.124352  0.361111  0.372973  0.309783  0.361111
# 58  0.005848  0.146465  0.377049  0.394444  0.335135  0.338983
# 59  0.005814  0.159794  0.389831  0.360656  0.294444  0.357955
# 60  0.023529  0.139175  0.397790  0.368132  0.312849  0.375000
#
# [61 rows x 14401 columns]

# %%
start = time.time()
df.to_csv(vid_name + ".csv", header=False, index=False)
print(time.time() - start)
# Out:
# 3.3215298652648926

# %%
start = time.time()
new_df = pd.read_csv(vid_name + ".csv", header=None)
print(time.time() - start)
new_df
# Out:
# 1.5653352737426758
#     0         1         2         3         4         5         6      \
# 0    10.0  0.380952  0.365079  0.349206  0.365079  0.376984  0.384921
# 1    10.0  0.401015  0.435644  0.338645  0.333333  0.324000  0.344130
# 2    10.0  0.435897  0.402062  0.322314  0.354582  0.337349  0.358566
# 3    10.0  0.410811  0.475410  0.334677  0.322449  0.318725  0.286290
# 4    10.0  0.420213  0.391534  0.351020  0.355102  0.340081  0.357430
# ..    ...       ...       ...       ...       ...       ...       ...
# 56   10.0  0.451429  0.455556  0.346939  0.323770  0.342742  0.315789
# 57   10.0  0.472826  0.442708  0.341463  0.327801  0.334694  0.368421
# 58   10.0  0.488372  0.491620  0.338710  0.315574  0.329317  0.357430
# 59   10.0  0.415789  0.394089  0.317073  0.313008  0.340081  0.345528
# 60   10.0  0.434555  0.425743  0.342857  0.334694  0.345382  0.318725
#
#        7         8         9      ...     14391     14392     14393     14394  \
# 0   0.369048  0.376984  0.384921  ...  0.115079  0.111111  0.027778  0.039683
# 1   0.315789  0.351240  0.314286  ...  0.151515  0.093567  0.045198  0.064516
# 2   0.361111  0.329268  0.315789  ...  0.198830  0.088235  0.005952  0.010753
# 3   0.317073  0.325203  0.303279  ...  0.186335  0.062893  0.000000  0.056497
# 4   0.338710  0.319672  0.309917  ...  0.220339  0.064000  0.055556  0.054645
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 56  0.318367  0.325203  0.327935  ...  0.176871  0.100719  0.043210  0.038251
# 57  0.341463  0.320988  0.340164  ...  0.155172  0.090361  0.036364  0.016484
# 58  0.330612  0.349794  0.334694  ...  0.119048  0.094937  0.049080  0.027624
# 59  0.336032  0.333333  0.337349  ...  0.128834  0.141104  0.018868  0.032967
# 60  0.370518  0.336032  0.318548  ...  0.128655  0.119760  0.075000  0.016667
#
#        14395     14396     14397     14398     14399     14400
# 0   0.059524  0.115079  0.309524  0.337302  0.206349  0.277778
# 1   0.005814  0.159794  0.355556  0.431034  0.346369  0.390110
# 2   0.028902  0.206349  0.494253  0.426966  0.400000  0.441860
# 3   0.012422  0.167568  0.458824  0.395210  0.349112  0.416185
# 4   0.050562  0.145833  0.366279  0.374269  0.314607  0.361111
# ..       ...       ...       ...       ...       ...       ...
# 56  0.040936  0.161458  0.360000  0.349727  0.294444  0.373563
# 57  0.016949  0.124352  0.361111  0.372973  0.309783  0.361111
# 58  0.005848  0.146465  0.377049  0.394444  0.335135  0.338983
# 59  0.005814  0.159794  0.389831  0.360656  0.294444  0.357955
# 60  0.023529  0.139175  0.397790  0.368132  0.312849  0.375000
#
# [61 rows x 14401 columns]
