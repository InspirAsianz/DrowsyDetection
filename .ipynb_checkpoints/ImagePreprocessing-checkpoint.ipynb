# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import time

# %%
vid_name = "01-05"
rank = 5
video = cv2.VideoCapture(vid_name + ".MOV")
_, frame = video.read()

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
cropped = gray[x1:x2, y1:y2]
resize_crop = cv2.resize(gray, (90, 160))
plt.imshow(resize_crop, cmap="gray")

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
resize_crop = resize_crop.flatten()
scaled = scaler.fit_transform(resize_crop.reshape(-1, 1))
scaled = np.append(np.array([rank]), scaled).reshape(1, -1)
global df
df = pd.DataFrame(scaled)
df
# Out:
#    0        1        2        3         4         5         6         7      \
# 0    5.0  0.98374  0.97561  0.95935  0.947154  0.902439  0.926829  0.922764
#
#       8         9      ...     14391     14392     14393     14394     14395  \
# 0  0.918699  0.918699  ...  0.808943  0.833333  0.792683  0.776423  0.752033
#
#       14396     14397     14398     14399     14400
# 0  0.638211  0.504065  0.569106  0.626016  0.666667
#
# [1 rows x 14401 columns]

# %%
def get_frame(sec):
    video.set(cv2.CAP_PROP_POS_MSEC, sec*1000)
    success, image = video.read()
    return success, image

# %%
def get_data(sec):
    global df
    start = time.time()
    success, image  = get_frame(sec)
    if not success:
        return
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(cropped, (90, 160))
    scaled = scaler.fit_transform(resized).flatten()
    scaled = np.append(np.array([rank]), scaled).flatten()
    df = df.append(pd.Series(scaled), ignore_index=True)

df
# Out:
#    0        1        2        3         4         5         6         7      \
# 0    5.0  0.98374  0.97561  0.95935  0.947154  0.902439  0.926829  0.922764
#
#       8         9      ...     14391     14392     14393     14394     14395  \
# 0  0.918699  0.918699  ...  0.808943  0.833333  0.792683  0.776423  0.752033
#
#       14396     14397     14398     14399     14400
# 0  0.638211  0.504065  0.569106  0.626016  0.666667
#
# [1 rows x 14401 columns]

# %%
start = time.time()
for i in range(1, 600, 10):
    elapsed = time.time() - start
    done = i/600
    estimate = int(elapsed/done - elapsed)
    print(f"Currently at {i//60} minutes and {i%60} seconds -- Estimated {estimate}s left          ", end="\r")
    
    get_data(i)

print(f"\nTook {elapsed} seconds to run")
df
# Out:
# Currently at 9 minutes and 51 seconds -- Estimated 0s left
# Took 33.76513600349426 seconds to run
#     0         1         2         3         4         5         6      \
# 0     5.0  0.983740  0.975610  0.959350  0.947154  0.902439  0.926829
# 1     5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 2     5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 3     5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 4     5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# ..    ...       ...       ...       ...       ...       ...       ...
# 56    5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 57    5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 58    5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 59    5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 60    5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
#
# ...

# %%
start = time.time()
df.to_csv(vid_name + ".csv", header=False, index=False)
print(time.time() - start)
# Out:
# 3.236699342727661

# %%
start = time.time()
new_df = pd.read_csv(vid_name + ".csv", header=None)
new_df.drop([0, 1])
print(time.time() - start)
new_df
# Out:
# 1.908898115158081
#     0         1         2         3         4         5         6      \
# 0     5.0  0.983740  0.975610  0.959350  0.947154  0.902439  0.926829
# 1     5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 2     5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 3     5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 4     5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# ..    ...       ...       ...       ...       ...       ...       ...
# 56    5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 57    5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 58    5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 59    5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
# 60    5.0  0.055814  0.056338  0.069767  0.164557  0.209091  0.258427
#
#        7         8         9      ...     14391     14392     14393     14394  \
# ...
