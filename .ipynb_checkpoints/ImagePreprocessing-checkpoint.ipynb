# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import time

# %%
vid_name = "26/10"
rank = 0
video = cv2.VideoCapture(vid_name + ".mp4")
_, frame = get_frame(15)

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
resize_crop = cv2.resize(gray, (180, 320))
plt.imshow(resize_crop, cmap="gray")

# %%
face_cascade = cv2.CascadeClassifier()
face_cascade.load("haarcascade_frontalface_default.xml")
# Out:
# True

# %%
faces = face_cascade.detectMultiScale(resize_crop)[0]
face_crop = resize_crop[faces[1]:faces[1]+faces[3], faces[0]:faces[0]+faces[2]]
plt.imshow(face_crop, cmap="gray")

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
resize_crop = resize_crop.flatten()
scaled = scaler.fit_transform(resize_crop.reshape(-1, 1))
scaled = np.append(np.array([rank]), scaled).reshape(1, -1)
scaled
# Out:
# array([[0.        , 1.        , 1.        , ..., 0.72803347, 0.28451883,
#         0.24686192]])

# %%
global df
df = pd.DataFrame()

# %%
def get_frame(sec):
    video.set(cv2.CAP_PROP_POS_MSEC, sec*1000)
    success, image = video.read()
    return success, image

# %%
def get_data(sec):
    global df
    success, image  = get_frame(sec)
    if not success:
        return
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(gray, (90, 160))
    scaled = scaler.fit_transform(resized).flatten()
    out = np.append(np.array([rank]), scaled).flatten()
    df = df.append(pd.Series(out), ignore_index=True)

# %%
def get_face(sec):
    global df
    success, image  = get_frame(sec)
    if not success:
        return
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    face_loc = face_cascade.detectMultiScale(gray, minSize=(50, 50))
    if len(face_loc) == 0:
        print("cant find")
        return
    face_loc = sorted(face_loc, key=lambda x:x[2], reverse=True)
    face_crop = gray[face_loc[0][1]:face_loc[0][1]+face_loc[0][3], face_loc[0][0]:face_loc[0][0]+face_loc[0][2]]
    face_crop = cv2.resize(face_crop, (56, 56))
    scaled = scaler.fit_transform(face_crop).flatten()
    out = np.append(np.array([rank]), scaled).flatten()
    df = df.append(pd.Series(out), ignore_index=True)

# %%
from mlxtend.image import extract_face_landmarks

# %%
def get_features(sec):
    global df
    success, image  = get_frame(sec)
    if not success:
        return
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    locations = extract_face_landmarks(gray)
    if not type(locations) == np.ndarray:
        print("cant find")
        return
    out = get_features_measurements(locations)
    out = np.append(np.array([rank]), out).flatten()
    df = df.append(pd.Series(out), ignore_index=True)

# %%
def get_features_measurements(locations):
    left = locations[36:42, :]
    right = locations[42:48, :]
    mouth = locations[48:60, :]
    
    left = sorted(left, key=lambda x : x[0])
    left_width = left[-1][0] - left[0][0]
    left = sorted(left, key=lambda x : x[1])
    left_height = left[-1][1] - left[0][1]

    right = sorted(right, key=lambda x : x[0])
    right_width = right[-1][0] - right[0][0]
    right = sorted(right, key=lambda x : x[1])
    right_height = right[-1][1] - right[0][1]
    
    mouth = sorted(mouth, key=lambda x : x[0])
    mouth_width = mouth[-1][0] - mouth[0][0]
    mouth = sorted(mouth, key=lambda x : x[1])
    mouth_height = mouth[-1][1] - mouth[0][1]
    
    face = sorted(locations, key=lambda x : x[0])
    face_width = face[-1][0] - face[0][0]
    face = sorted(locations, key=lambda x : x[1])
    face_height = face[-1][1] - face[0][1]
 

    return [left_width/face_width, left_height/face_height, right_width/face_width, right_height/face_height, mouth_width/face_width, mouth_height/face_height]

# %%
# entire picture
for p in ["01", "02", "03", "04", "05", "06"]:
    for r in [0, 5, 10]:
        vid_name = p + "/" + str(r)
        rank = r
        video = cv2.VideoCapture(vid_name + ".MOV")
        success, _ = video.read()
        if not success:
            video = cv2.VideoCapture(vid_name + ".mp4")
        
        start = time.time()
        df = pd.DataFrame()
        for i in range(0, 600, 10):
            elapsed = time.time() - start
            done = (i+1)/600
            estimate = int(elapsed/done - elapsed)
            print(f"Currently at {i//60} minutes and {i%60} seconds -- Estimated {estimate}s left on {vid_name}        ", end="\r")

            get_data(i)

        df.to_csv("data/" + p + "-" + str(r) + ".csv", header=False, index=False)

# %%
# only the face
for p in range(42, 49):
    for r in [0, 10]:
        vid_name = str(p) + "/" + str(r)
        rank = r
        video = cv2.VideoCapture(vid_name + ".MOV")
        success, _ = video.read()
        if not success:
            video = cv2.VideoCapture(vid_name + ".mp4")
        
        start = time.time()
        df = pd.DataFrame()
        for i in range(0, 601, 15):
            elapsed = time.time() - start
            done = (i+1)/600
            estimate = int(elapsed/done - elapsed)
            print(f"Currently at {i//60} minutes and {i%60} seconds -- Estimated {estimate}s left on {vid_name}        ", end="\r")

            get_face(i)

        df.to_csv("face data/" + str(p) + "-" + str(r) + ".csv", header=False, index=False)
# Out:
# cant find at 0 minutes and 45 seconds -- Estimated 19s left on 42/0
# cant find at 3 minutes and 15 seconds -- Estimated 12s left on 42/0
# cant find at 3 minutes and 30 seconds -- Estimated 12s left on 42/0
# cant find at 6 minutes and 30 seconds -- Estimated 6s left on 42/0
# cant find at 7 minutes and 45 seconds -- Estimated 4s left on 42/0
# cant find at 1 minutes and 45 seconds -- Estimated 15s left on 42/10
# cant find at 2 minutes and 0 seconds -- Estimated 14s left on 42/10
# cant find at 2 minutes and 15 seconds -- Estimated 14s left on 42/10
# cant find at 2 minutes and 30 seconds -- Estimated 13s left on 42/10
# cant find at 3 minutes and 30 seconds -- Estimated 12s left on 42/10
# cant find at 3 minutes and 45 seconds -- Estimated 12s left on 42/10
# cant find at 4 minutes and 15 seconds -- Estimated 11s left on 42/10
# cant find at 4 minutes and 30 seconds -- Estimated 10s left on 42/10
# cant find at 4 minutes and 45 seconds -- Estimated 10s left on 42/10
# cant find at 5 minutes and 15 seconds -- Estimated 9s left on 42/10
# cant find at 5 minutes and 30 seconds -- Estimated 8s left on 42/10
# cant find at 6 minutes and 15 seconds -- Estimated 7s left on 42/10
# cant find at 7 minutes and 0 seconds -- Estimated 5s left on 42/10
# cant find at 7 minutes and 15 seconds -- Estimated 5s left on 42/10
# cant find at 7 minutes and 30 seconds -- Estimated 4s left on 42/10
# cant find at 7 minutes and 45 seconds -- Estimated 4s left on 42/10
# cant find at 8 minutes and 0 seconds -- Estimated 3s left on 42/10
# cant find at 8 minutes and 30 seconds -- Estimated 2s left on 42/10
# cant find at 8 minutes and 45 seconds -- Estimated 2s left on 42/10
# cant find at 9 minutes and 15 seconds -- Estimated 1s left on 42/10
# cant find at 9 minutes and 30 seconds -- Estimated 0s left on 42/10
# cant find at 10 minutes and 0 seconds -- Estimated 0s left on 42/10
# cant find at 5 minutes and 15 seconds -- Estimated 6s left on 43/0
# cant find at 5 minutes and 0 seconds -- Estimated 7s left on 48/10
# cant find at 5 minutes and 15 seconds -- Estimated 7s left on 48/10
# cant find at 5 minutes and 30 seconds -- Estimated 6s left on 48/10
# cant find at 5 minutes and 45 seconds -- Estimated 6s left on 48/10
# cant find at 6 minutes and 0 seconds -- Estimated 5s left on 48/10
# cant find at 6 minutes and 15 seconds -- Estimated 5s left on 48/10
# cant find at 6 minutes and 30 seconds -- Estimated 5s left on 48/10
# cant find at 8 minutes and 15 seconds -- Estimated 2s left on 48/10
# cant find at 8 minutes and 30 seconds -- Estimated 2s left on 48/10
# cant find at 8 minutes and 45 seconds -- Estimated 1s left on 48/10
# cant find at 9 minutes and 0 seconds -- Estimated 1s left on 48/10
# cant find at 9 minutes and 15 seconds -- Estimated 1s left on 48/10
# cant find at 9 minutes and 45 seconds -- Estimated 0s left on 48/10
# Currently at 10 minutes and 0 seconds -- Estimated 0s left on 48/10

# %%
# facial features
for p in range(42, 49):
    for r in [0, 10]:
        vid_name = str(p) + "/" + str(r)
        rank = r
        video = cv2.VideoCapture(vid_name + ".MOV")
        success, _ = video.read()
        if not success:
            video = cv2.VideoCapture(vid_name + ".mp4")
        
        start = time.time()
        df = pd.DataFrame()
        for i in range(0, 601, 30):
            elapsed = time.time() - start
            done = (i+1)/600
            estimate = int(elapsed/done - elapsed)
            print(f"Currently at {i//60} minutes and {i%60} seconds -- Estimated {estimate}s left on {vid_name}        ", end="\r")

            get_features(i)

        df.to_csv("feature data/" + str(p) + "-" + str(r) + ".csv", header=False, index=False)
# Out:
# Currently at 1 minutes and 30 seconds -- Estimated 33s left on 42/10
# c:\users\andre\appdata\local\programs\python\python38\lib\site-packages\mlxtend\image\extract_face_landmarks.py:66: UserWarning: No face detected.
#   warnings.warn('No face detected.')
# cant find
# cant find at 6 minutes and 0 seconds -- Estimated 15s left on 42/10
# cant find at 9 minutes and 30 seconds -- Estimated 1s left on 42/10
# cant find at 7 minutes and 0 seconds -- Estimated 5s left on 43/10
# cant find at 8 minutes and 30 seconds -- Estimated 2s left on 43/10
# cant find at 4 minutes and 0 seconds -- Estimated 23s left on 48/10
# cant find at 4 minutes and 30 seconds -- Estimated 21s left on 48/10
# cant find at 5 minutes and 0 seconds -- Estimated 19s left on 48/10
# cant find at 5 minutes and 30 seconds -- Estimated 17s left on 48/10
# cant find at 6 minutes and 0 seconds -- Estimated 15s left on 48/10
# Currently at 10 minutes and 0 seconds -- Estimated 0s left on 48/10
