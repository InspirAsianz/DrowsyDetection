# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
import os
all_dfs = []
directory = os.fsencode("feature data/")
for file in os.listdir(directory):
     filename = os.fsdecode(file)
     if filename.endswith("0.csv"): 
         all_dfs.append(pd.read_csv("feature data/" + filename, header=None))

# %%
df1_0 = pd.read_csv("data/01-0.csv", header=None)
df1_5 = pd.read_csv("data/01-5.csv", header=None)
df1_10 = pd.read_csv("data/01-10.csv", header=None)
df2_0 = pd.read_csv("data/02-0.csv", header=None)
df2_5 = pd.read_csv("data/02-5.csv", header=None)
df2_10 = pd.read_csv("data/02-10.csv", header=None)

# %%
data = pd.concat(all_dfs) # [df1_0, df1_5, df1_10, df2_0, df2_5, df2_10])
data
# Out:
#        0         1         2         3         4         5         6
# 0    0.0  0.193878  0.060185  0.181122  0.062500  0.344388  0.131944
# 1    0.0  0.185279  0.059908  0.159898  0.064516  0.327411  0.135945
# 2    0.0  0.183168  0.051454  0.148515  0.058166  0.316832  0.131991
# 3    0.0  0.178756  0.048611  0.168394  0.053241  0.341969  0.120370
# 4    0.0  0.180662  0.047506  0.152672  0.047506  0.318066  0.125891
# ..   ...       ...       ...       ...       ...       ...       ...
# 16  10.0  0.169096  0.066667  0.177843  0.054545  0.346939  0.148485
# 17  10.0  0.165165  0.039514  0.171171  0.048632  0.360360  0.142857
# 18  10.0  0.164740  0.038690  0.176301  0.035714  0.369942  0.142857
# 19  10.0  0.161111  0.046784  0.172222  0.046784  0.336111  0.143275
# 20  10.0  0.173134  0.042296  0.182090  0.039275  0.364179  0.145015
#
# [484 rows x 7 columns]

# %%
data = pd.read_csv("feature data/scaled.csv")
data
# Out:
#         0  Left Eye Width  Left Eye Height  Right Eye Width  Right Eye Height  \
# 0     0.0        0.709524         0.475776         0.691477          0.454649
# 1     0.0        0.589949         0.472364         0.525904          0.476794
# 2     0.0        0.560594         0.368381         0.437098          0.407039
# 3     0.0        0.499240         0.333411         0.592178          0.352945
# 4     0.0        0.525734         0.319817         0.469527          0.289953
# ..    ...             ...              ...              ...               ...
# 479  10.0        0.364898         0.555501         0.665890          0.367276
# 480  10.0        0.310230         0.221509         0.613845          0.302325
# 481  10.0        0.304316         0.211383         0.653861          0.160434
# 482  10.0        0.253852         0.310932         0.622044          0.282020
# 483  10.0        0.421055         0.255733         0.699022          0.199544
#
#      Mouth Width  Mouth Height
# 0       0.428024      0.389152
# 1       0.329413      0.406707
# 2       0.267960      0.389357
# 3       0.413974      0.338359
# 4       0.275131      0.362585
# ..           ...           ...
# 479     0.442842      0.461740
# 480     0.520804      0.437043
# 481     0.576461      0.437043
# 482     0.379948      0.438876
# 483     0.542985      0.446513
#
# [484 rows x 7 columns]

# %%
X = data.iloc[:, [i for i in range(1, 7)]]
Y = data.iloc[:, 0]
X
# Out:
#      Left Eye Width  Left Eye Height  Right Eye Width  Right Eye Height  \
# 0          0.709524         0.475776         0.691477          0.454649
# 1          0.589949         0.472364         0.525904          0.476794
# 2          0.560594         0.368381         0.437098          0.407039
# 3          0.499240         0.333411         0.592178          0.352945
# 4          0.525734         0.319817         0.469527          0.289953
# ..              ...              ...              ...               ...
# 479        0.364898         0.555501         0.665890          0.367276
# 480        0.310230         0.221509         0.613845          0.302325
# 481        0.304316         0.211383         0.653861          0.160434
# 482        0.253852         0.310932         0.622044          0.282020
# 483        0.421055         0.255733         0.699022          0.199544
#
#      Mouth Width  Mouth Height
# 0       0.428024      0.389152
# 1       0.329413      0.406707
# 2       0.267960      0.389357
# 3       0.413974      0.338359
# 4       0.275131      0.362585
# ..           ...           ...
# 479     0.442842      0.461740
# 480     0.520804      0.437043
# 481     0.576461      0.437043
# 482     0.379948      0.438876
# 483     0.542985      0.446513
#
# [484 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size = 0.20, shuffle=False)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
X2 = pca.fit_transform(X)
X_Train2 = pca.fit_transform(X_Train)
X_Test2 = pca.fit_transform(X_Test)

# %%
zeroes = []
fives = []
tens = []
for i in range(0, len(Y)):
    if (Y.iloc[i] == 0):
#         zeroes.append([X2[i][0], X2[i][1]])
        zeroes.append(X.iloc[i, :])
    if (Y.iloc[i] == 10):
#         tens.append([X2[i][0], X2[i][1]])
        tens.append(X.iloc[i, :])

zeroes = np.array(zeroes)
tens = np.array(tens)

for i in range(6):
    for j in range(6):
        if i == j:
            continue
        plt.scatter(zeroes[:, i], zeroes[:, j], color="blue")
        plt.scatter(tens[:, i], tens[:, j], color="green")
        plt.title(X.columns[j] + " vs " + X.columns[i])
        plt.xlabel(X.columns[i])
        plt.ylabel(X.columns[j])
        plt.show()

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = "poly")
classifier.fit(X_Train2, Y_Train)
# Out:
# SVC(kernel='poly')

# %%
from sklearn.metrics import accuracy_score
Y_Pred = classifier.predict(X_Test2)
accuracy = accuracy_score(Y_Test, Y_Pred)
accuracy
# Out:
# 0.32989690721649484

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X=X2, 
                      y=np.array(Y).astype(np.int64),
                      clf=classifier, 
                      legend=2)

plt.xlabel(X.columns[0], size=14)
plt.ylabel(X.columns[1], size=14)
plt.title('SVM Decision Region Boundary', size=16)
# Out:
# Text(0.5, 1.0, 'SVM Decision Region Boundary')
