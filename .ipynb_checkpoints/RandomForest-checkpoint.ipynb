# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
import os
all_dfs = []
directory = os.fsencode("face data/")
for file in os.listdir(directory):
     filename = os.fsdecode(file)
     if filename.endswith("0.csv"): 
         all_dfs.append(pd.read_csv("face data/" + filename, header=None))
len(all_dfs)
# Out:
# 24

# %%
data = pd.concat(all_dfs)
pd.set_option('display.max_rows', 10)
data
# Out:
#      0         1         2         3         4         5         6    \
# 0    0.0  0.188679  0.152284  0.013953  0.011299  0.716981  0.903704
# 1    0.0  0.321429  0.115385  0.000000  0.210843  0.465969  0.894309
# 2    0.0  0.185022  0.143519  0.063063  0.000000  0.513333  0.767606
# 3    0.0  0.472826  0.264151  0.065421  0.000000  0.598540  0.769737
# 4    0.0  0.266234  0.153488  0.074074  0.000000  0.570470  0.796875
# ..   ...       ...       ...       ...       ...       ...       ...
# 15  10.0  0.200000  0.166667  0.090909  0.800000  0.000000  0.218310
# 16  10.0  0.000000  0.076923  0.000000  0.767857  0.045455  0.073529
# 17  10.0  0.100000  0.000000  0.000000  0.551724  0.044444  0.090909
# 18  10.0  0.000000  0.100000  0.214286  0.855422  0.273684  0.053030
# 19  10.0  0.000000  0.100000  0.181818  0.904762  0.121212  0.150376
#
#          7         8         9    ...       775       776       777       778  \
# 0   0.940397  0.920290  0.949640  ...  0.042254  0.021429  0.242857  0.280899
# 1   0.914062  0.927007  0.909774  ...  0.048485  0.000000  0.300000  0.179724
# 2   0.854167  0.896296  0.862069  ...  0.302013  0.170068  0.235577  0.066667
# 3   0.912409  0.891667  0.850340  ...  0.006410  0.013605  0.202703  0.094340
# 4   0.921429  0.909774  0.868966  ...  0.000000  0.355263  0.068027  0.219512
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 15  0.356250  0.251534  0.000000  ...  0.741667  0.825175  0.778523  0.876543
# 16  0.278481  0.145161  0.096774  ...  0.854839  0.807143  0.842105  0.968037
# 17  0.190083  0.000000  0.000000  ...  0.850746  0.803279  0.875776  0.993377
# 18  0.264516  0.138889  0.233083  ...  0.779412  0.837838  0.840909  0.957831
# 19  0.414013  0.092199  0.000000  ...  0.814607  0.801471  0.708955  0.844720
#
#          779       780       781       782       783       784
# 0   0.211268  0.189055  0.085714  0.000000  0.000000  0.000000
# 1   0.153846  0.098901  0.000000  0.000000  0.000000  0.093750
# 2   0.000000  0.086614  0.000000  0.000000  0.000000  0.000000
# 3   0.142157  0.122807  0.123596  0.000000  0.729730  0.365854
# 4   0.113990  0.052941  0.302521  0.000000  0.217391  0.325581
# ..       ...       ...       ...       ...       ...       ...
# 15  1.000000  0.890476  0.275000  0.201923  0.467836  0.016667
# 16  1.000000  0.174129  0.096154  0.000000  0.000000  0.050847
# 17  0.000000  0.229167  0.652381  0.594203  0.180328  0.108108
# 18  0.986111  0.231818  0.004854  0.035000  0.000000  0.443820
# 19  1.000000  0.077295  0.107143  0.217822  0.000000  0.419753
#
# [469 rows x 785 columns]

# %%
data = pd.read_csv("feature data/scaled.csv")
data
# Out:
#         0  Left Width  Left Height  Right Width  Right Height  Mouth Width  \
# 0     0.0    0.580300     0.060185     0.181122      0.062500     0.344388
# 1     0.0    0.580605     0.051454     0.148515      0.058166     0.316832
# 2     0.0    0.540684     0.047506     0.152672      0.047506     0.318066
# 3     0.0    0.398224     0.047722     0.148780      0.047722     0.326829
# 4     0.0    0.552260     0.063830     0.166667      0.066194     0.341146
# ..    ...         ...          ...          ...           ...          ...
# 251  10.0    0.657432     0.042813     0.179641      0.036697     0.350299
# 252  10.0    0.640243     0.027607     0.177177      0.033742     0.348348
# 253  10.0    0.688542     0.066667     0.177843      0.054545     0.346939
# 254  10.0    0.651714     0.038690     0.176301      0.035714     0.369942
# 255  10.0    0.665836     0.042296     0.182090      0.039275     0.364179
#
#      Mouth Height
# 0        0.131944
# 1        0.131991
# 2        0.125891
# 3        0.104121
# 4        0.127660
# ..            ...
# 251      0.143731
# 252      0.141104
# 253      0.148485
# 254      0.142857
# 255      0.145015
#
# [256 rows x 7 columns]

# %%
X = data.iloc[:, [i for i in range(1, 7)]]
Y = data.iloc[:, 0]

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size = 0.20, shuffle=False)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 25, max_depth = 10, criterion = 'entropy', bootstrap=False)
classifier.fit(X_Train,Y_Train)
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_depth=10,
#                        n_estimators=25)

# %%
from sklearn.metrics import accuracy_score
Y_Pred = classifier.predict(X_Test)
accuracy = accuracy_score(Y_Test, Y_Pred)
accuracy
# Out:
# 0.7115384615384616

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(classifier, X_Test, Y_Test, normalize="true")

# %%
from IPython.display import SVG
from graphviz import Source
from sklearn.tree import export_graphviz
graph = Source( export_graphviz(classifier[0], out_file=None, feature_names=X.columns, class_names = ["Non-Drowsy", "Drowsy"]))
graph.format = 'png'
graph.render('dtree_render',view=True)
# Out:
# 'dtree_render.png'

# %%
import joblib
joblib.dump(classifier, "rf_model.joblib")
# Out:
# ['rf_model.joblib']
